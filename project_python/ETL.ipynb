# %%
from Exploration_Phase import extract_data
from Transform_Phase import transform_data
from Loading_Phase import load_data

def run_pipeline():
    sales=r'C:\Users\marim\Downloads\data\Sales.json'
    forecast=r'C:\Users\marim\Downloads\data\forecast.json'
    raw_sales, raw_forecast = extract_data(sales, forecast)
    processed_tables = transform_data(raw_sales, raw_forecast)
    load_data(processed_tables)

if __name__ == "__main__":
    run_pipeline()
# Out:
# --- Start Extraction Phase ---
# Rows loaded: 33
#   CountryRegion            Brand  Forecast  Year
# 0         China         A. Datum    201487  2009
# 1         China  Adventure Works    399490  2009
# 2         China          Contoso   1173308  2009
# 3         China         Fabrikam    790074  2009
# 4         China          Litware    437443  2009
#
# Data Quality Issues in Forecast:
# Missing Values:
#  CountryRegion    0
# Brand            0
# Forecast         0
# Year             0
# dtype: int64
#
# Data Types:
#  CountryRegion      str
# Brand              str
# Forecast         int64
# Year             int64
# dtype: object
#
# Duplicate Values in Forecast (per column):
# - CountryRegion: 30
# - Brand: 22
# - Forecast: 0
# - Year: 32
#
# Total Duplicate Rows in Forecast: 0
# Rows loaded: 298246
#    ProductKey                                       Product Name    Brand  \
# 0        2492  Cigarette Lighter Adapter for Contoso Phones E...  Contoso
# ...
